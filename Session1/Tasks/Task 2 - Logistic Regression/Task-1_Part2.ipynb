# %% [markdown]
# <a href="https://colab.research.google.com/github/adulu-bang/ML_BOOTCAMP_24_IET_NITK/blob/main/Session1/Tasks/Task%202%20-%20Logistic%20Regression/Task-1_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧑‍🏫 Task 1 Part 2: Build Your Own Logistic Regression Model for Sentiment Analysis
# In this exercise, you will build a **logistic regression model** from scratch to perform sentiment analysis.
#
# **Objective:** Implement all key components of an ML pipeline (except for data handling).
#
# **Allowed Libraries:** `pandas`, `numpy`
#
# **Not Allowed:** Any pre-built ML algorithms or functions like `LogisticRegression` from `sklearn`.
#
# Follow the instructions step-by-step and answer the questions!

# %% [markdown]
# ## Step 1: Load the Data
# **Task:** Use `pandas` to load the dataset from a file named `IMDB_reviews.csv`.
#
# > **Hint:** Use `pd.read_csv()` to load the file and display the first 5 rows.
#
# **Question:** What are the key features and the target variable in this dataset?

# %%
# Load the dataset and display the first few rows
import pandas as pd
import numpy as np

reviews=pd.read_csv('/content/IMDB_Dataset.csv')
reviews.head()

#key feature: the review,  target variable:sentiment
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ## Step 3: Tokenization and Text Cleaning
# **Task:** Implement your own function to:
# 1. Convert all text to lowercase.
# 2. Remove punctuation and special characters.
# 3. Split the text into words (tokenization).
#
# > **Hint:** Use Python string methods and list comprehensions.
#
# **Question:** Why is tokenization important for text-based models?

# %%
#Write your own tokenizer function

import re



def tokenizer(text):
         text = text.lower()  # converts to lowr case
         text = re.sub(r'[^\w\s]', '', text)  # remov punct and special char
         tokens = text.split() # splits into separate words
         return tokens

'''a= tokenizer("This, !s a t$est.!")
print(a)
print("\n")

b= tokenizer(reviews['review'][0])
print(b)'''


tokenized_reviews = [tokenizer(review) for review in reviews['review']]
print(tokenized_reviews[20])









#this tokenization is imp in text-based models bec these individual words are often used..
#as features and their freq is observed to make predictions on the text.
#also, tokenization helps create a list of unique words(tokens), with each being assigned a numerical index.
#It also reduces the no. of things to process, as we no more need to process punctuations, spl characters etc.
# Out:
# ['after', 'the', 'success', 'of', 'die', 'hard', 'and', 'its', 'sequels', 'its', 'no', 'surprise', 'really', 'that', 'in', 'the', '1990s', 'a', 'glut', 'of', 'die', 'hard', 'on', 'a', 'movies', 'cashed', 'in', 'on', 'the', 'wrong', 'guy', 'wrong', 'place', 'wrong', 'time', 'concept', 'that', 'is', 'what', 'they', 'did', 'with', 'cliffhanger', 'die', 'hard', 'on', 'a', 'mountain', 'just', 'in', 'time', 'to', 'rescue', 'sly', 'stop', 'or', 'my', 'mom', 'will', 'shoot', 'stallones', 'careerbr', 'br', 'cliffhanger', 'is', 'one', 'big', 'nitpickers', 'dream', 'especially', 'to', 'those', 'who', 'are', 'expert', 'at', 'mountain', 'climbing', 'basejumping', 'aviation', 'facial', 'expressions', 'acting', 'skills', 'all', 'in', 'all', 'its', 'full', 'of', 'excuses', 'to', 'dismiss', 'the', 'film', 'as', 'one', 'overblown', 'pile', 'of', 'junk', 'stallone', 'even', 'managed', 'to', 'get', 'outacted', 'by', 'a', 'horse', 'however', 'if', 'you', 'an', 'forget', 'all', 'the', 'nonsense', 'its', 'actually', 'a', 'very', 'lovable', 'and', 'undeniably', 'entertaining', 'romp', 'that', 'delivers', 'as', 'plenty', 'of', 'thrills', 'and', 'unintentionally', 'plenty', 'of', 'laughsbr', 'br', 'youve', 'got', 'to', 'love', 'john', 'lithgows', 'sneery', 'evilness', 'his', 'tick', 'every', 'box', 'band', 'of', 'baddies', 'and', 'best', 'of', 'all', 'the', 'permanently', 'harassed', 'and', 'hapless', 'turncoat', 'agent', 'rex', 'linn', 'as', 'traversbr', 'br', 'he', 'may', 'of', 'been', 'henry', 'in', 'portrait', 'of', 'a', 'serial', 'killer', 'but', 'michael', 'rooker', 'is', 'noteworthy', 'for', 'a', 'cringeworthy', 'performance', 'as', 'hal', 'he', 'insists', 'on', 'constantly', 'shrieking', 'in', 'painful', 'disbelief', 'at', 'his', 'captors', 'that', 'man', 'never', 'hurt', 'anybody', 'and', 'whilst', 'he', 'surely', 'cant', 'be', 'it', 'really', 'does', 'look', 'like', 'ralph', 'waites', 'frank', 'character', 'is', 'grinning', 'as', 'the', 'girl', 'plummets', 'to', 'her', 'deathbr', 'br', 'mention', 'too', 'must', 'go', 'to', 'former', 'londons', 'burning', 'actor', 'craig', 'fairbrass', 'as', 'the', 'brit', 'bad', 'guy', 'who', 'comes', 'a', 'cropper', 'whilst', 'using', 'hal', 'as', 'a', 'human', 'football', 'yes', 'you', 'cant', 'help', 'enjoy', 'that', 'bit', 'hal', 'needed', 'a', 'good', 'kickingbr', 'br', 'so', 'forget', 'your', 'better', 'judgement', 'who', 'cares', 'if', 'that', 'could', 'never', 'happen', 'lower', 'your', 'acting', 'expectations', 'turn', 'up', 'the', 'volume', 'and', 'enjoy', 'and', 'if', 'youre', 'looking', 'for', 'qaulen', 'hes', 'the', 'one', 'wearing', 'the', 'helicopter']

# %% [markdown]
# ## Step 4: Create a Vocabulary
# **Task:** Create a **vocabulary** (a list of unique words) from the tokenized dataset.
#
# > **Hint:** Use a set to store unique words, then convert it to a list.
#
# **Question:** How does vocabulary size affect model performance?

# %%
# Your code here

'''def create_vocabulary(tokenized_dataset):

    vocabulary = set()  # Use a set to store unique words
    for review_tokens in tokenized_dataset:

            vocabulary.add(review_tokens)
    return list(vocabulary)  # Convert the set to a list

# Example usage (assuming you have a list of tokenized reviews called 'tokenized_reviews')
vocabulary = create_vocabulary( tokenized_reviews)
print(vocabulary)

'''


def create_vocabulary(tokenized_dataset):
    vocabulary = set()  # Use a set to store unique words in reviews
    for review_tokens in tokenized_dataset:
        # iteration through individual tokens in each review
        for token in review_tokens:
            vocabulary.add(token)  # Add each token to the vocabulary set
    return list(vocabulary)  # Convert the set to a list


vocabulary = create_vocabulary(tokenized_reviews)
print(vocabulary)
# Out:
# ['macadder', 'tricksy', 'undermines', 'gulfs', 'bolted', 'thatcher', 'jrshows', 'leveraged', 'godhis', 'adorble', '1962', 'polarisdib', 'taryn', 'tarnishes', 'mmmmm', 'accountand', 'sexythis', 'togetheri', '383br', 'harlines', 'vehical', 'michels', 'rediculous', 'nonamed', 'charleston', 'agonized', 'rom', 'thielemansbr', 'elementsit', 'jodys', 'sociologists', 'productivity', 'kidnappinghow', 'flatmate', 'cantmiss', 'directorstar', 'repelling', 'goods', 'debralee', 'natassja', 'surfingbut', 'uttered', 'resoloution', 'livedlife', 'doofus', 'dividians', 'sayfirst', 'burqas', 'agendaheart', 'hotd2', 'semicleared', 'grandmotherinspired', 'toussaint', 'cautioning', 'disfiguration', 'benis', 'wasoh', 'colloquial', 'ultradull', '98br', 'london', 'japaneseamericans', 'hayworths', 'cortland', 'mrsuperintuitiveicanfigureoutanything', 'oafiest', 'charactersunrealistic', 'transferring', 'ninetofive', 'medalthis', 'universe1940', 'serlingesq', 'unaffected', 'hurtful', 'islandnation', 'genuingly', 'bronzes', '95100', 'bejarano', 'hoursreminder', 'fabian', 'housing', 'holder', 'contortionist', 'datethis', 'bisaya', 'racialbr', 'judicially', 'dinglehopper', 'roiling', 'sapling', 'telerealistic', 'religionwise', 'contemplatebr', 'reworking', 'klinger', 'weedon', 'bricksbr', 'refracted', 'humbleyetproud', '1959', 'doorman', 'orchestrated', 'darktoned', 'dicebr', 'mfn', 'luchador', 'fredrikstad', 'biskinds', 'alexanderplatz', 'venteran', 'prefaced', 'hulette', 'drivels', 'movementwhen', 'secondbanana', 'arribas', 'lionbr', 'muchcelebrated', 'outlets', 'geisels', 'flowery', 'mortresnais', 'overexxagerating', 'unhousebroken', 'linesman', 'noonemoreindependentnonamerican', 'disposalbr', 'himselfwho', 'unprejudiced', 'hu', 'pumpkincarving', 'nonsequel', 'owlwrangling', 'decadent', 'mandalar', 'clayburgh', 'idealbr', 'fontaine', 'thickheaded', 'hospitalhe', 'constitutionally', 'tsuyako', 'lambastingbr', 'fakeness', 'indemand', 'husbandwife', 'igor', 'pales', 'braverybr', 'adhesive', 'fedup', 'fairplay', 'moggys', 'giorgio', 'laughedkids', 'nemo', 'israel', 'tinker', 'leisen', 'filmtape', 'shuang', 'gratifyingbr', 'resiliency', 'mammarian', 'bjamin', 'swat', 'tenuta', 'bogglingly', 'actionmovie', 'hawkss', 'nottooconvincing', 'itrichard', 'phiiistine', 'eitheri', 'innovatively', 'plotdevice', 'mas', 'moratorium', 'octasacks', 'voicedplayed', 'astley', 'parallels', 'australia', 'oar', 'alaskey', 'doran', 'torti', 'santo', 'somethinbr', 'heroicly', 'achala', 'haldane', 'illboth', 'morningstar1958', 'burgialien', 'straightgay', 'warriorbr', 'austion', 'ultimate', 'linneys', 'braid', 'licensegetting', 'titanica', 'welldressed', 'contentles', 'propmaster', 'wayon', 'smithapatel', 'austriani', 'vernetales', 'hotdog', 'uncool', 'selfinvolving', 'annm', 'congolese', 'saroor', 'artificiality', 'esthetical', 'dent', 'crale', 'lartbr', 'auditions', 'hecht', 'gotbr', 'happytobeinterviewed', 'mindbender', 'gratefully', 'overlyrehearsed', 'libbybr', 'understorey', 'purged', 'paluzzi', 'hadand', 'leartes', 'astrologist', 'nuthin', '12s', 'dryden', 'brannon', 'w3atch', 'sourcesbr', 'destinationjet', 'masks', 'brin', 'nannystate', 'bodyparts', 'sleepgassing', 'wilkinsons', 'bronteized', 'courses', 'kidnapping', 'mozambique', 'infiltrated', 'fing', 'nonfact', 'irrepairable', 'doctorturnedvigilante', 'fascinate', 'sols', 'moxie', 'raunch', 'atlanticwhile', 'horsetocoach', 'creaturesand', 'fortiers', 'dummie', 'disturbingfrightening', 'antagonized', 'loyvek', 'tawny', 'fromonce', 'moodsbr', 'bubblebr', 'wellread', 'chaingangs', 'packagebr', 'dustbr', 'patriots', 'erbr', 'whitherspoon', 'hummer', 'singelton', 'portrayers', 'denounces', 'cringes', 'outnot', 'sterilize', 'vukovar', 'earsand', 'allegation', 'measurably', 'uhis', 'understate', 'superstarit', 'tvone', 'keysbr', 'gershwin', 'synchronization', 'mercies', 'argila', 'isntonly', 'nickerson', 'hollywoodat', 'inspirationalso', 'shined', 'westpoint', 'layabouts', 'signhit', 'ownexcept', 'mocked', 'hayakawas', 'yaargh', ...

# %% [markdown]
# ## Step 5: Implement Word Count
# **Task:** Calculate and store the number of times each word appears in a particular review for all reviews

# %%
# Your code here
# Example: Write functions to calculate word counts

def calculate_word_counts(tokenized_reviews, vocabulary):
    word_counts = []  # Initialize an empty list to store word counts for each review
    for review_tokens in tokenized_reviews:
        review_word_count = {}  # Initialize a dictionary to store word counts for the current review
        for word in vocabulary:
            review_word_count[word] = review_tokens.count(word)  # Count occurrences of each word in the vocabulary
        word_counts.append(review_word_count)  # Add the review's word counts to the list
    return word_counts  # Return the list of word counts for all reviews

# Example usage:
word_counts = calculate_word_counts(tokenized_reviews, vocabulary)
print(word_counts[0])  # This will print the word counts for the first review

# %% [markdown]
# ## Step 6: Train-Test Split
# **Task:** Split the data into **80% training** and **20% testing** sets.
#
# > **Hint:** Use `numpy` or list slicing to split the data manually.
#
# **Question:** Why do we need to split the data for training and testing?

# %%
# Your code here

# %% [markdown]
# ## Step 7: Building the Logistic Regression Model (Divided Steps)

# %% [markdown]
# ### Part 1: The Prediction functions
# The **prediction function** returns the predicted value of the data point using the weights and the bias. It uses the sigmoid function to convert the prediction into a value in the range of 0 to 1.
#
# **Task:** Implement the sigmoid and prediction functions

# %%
def sigmoid(x):
 return

def lr_prediction(weights,	bias,	features):
 return

# %% [markdown]
# ### Part 2: Implementing the Error functions
# **Task:** Use the gradient update rules to train the logistic regression model over multiple epochs.

# %%
def	log_loss(weights,	bias,	features,	label):
    return

def	total_log_loss(weights,	bias,	X,	y):
    return

# %% [markdown]
# ### Part 1: Update Weights
# The **Update_Weights** adjusts weights and bias based on whether points are correctly or incorrectly classified, It is a simple method of improving the model at every iteration:
# 1. **Correctly classified points:** Move the line **away** from the point.
# 2. **Incorrectly classified points:** Move the line **towards** the point.
#
# **Task:** Implement the gradient update function based on these rules.

# %%
#Your Code
def	lr_update_weights(weights,	bias,	features,	label,	learning_rate	=	0.01):
    return

# %% [markdown]
# ### Part 2: Implementing the Logistic Regression Algorithm
# **Task:** Use the function to update weights to train the logistic regression model over multiple epochs. Keep track of the total error for each epoch. You will later plot these errors.

# %%
# Implement the logistic regression model
def	lr_algorithm(features,	labels,	learning_rate	=	0.01,	epochs	=	200):
    return

# %% [markdown]
# ## Step 8: Evaluate Your Model
# **Task:** Calculate the accuracy of the model. Compare the predicted labels with the actual labels.
#
# > **Hint:** Use the formula for accuracy: (Correct Predictions / Total Predictions) * 100
#
# **Question:** Which metric—accuracy, precision, or recall—is most important for sentiment analysis?

# %%
# Your code here

# %% [markdown]
# ## Step 8: Visualize the Errors
# **Task:** Create a scatter plot of the total errors over the training epochs. The plot should show a gradual decrease in errors, stabilizing as the model converges.

# %%
#Your code here

# %% [markdown]
# ## Step 9: Make Predictions on New Data
# **Task:** Use your trained model to predict the sentiment of the following review:
#
# > _"The movie was absolutely fantastic and kept me hooked till the end."_
#
# **Question:** What challenges might arise when predicting on new data?

# %%
# Your code here

# %% [markdown]
# ## Step 10: Wrap-up
# 1. How well did your model perform?
# 2. What challenges did you face while implementing it from scratch?
# 3. What improvements would you suggest for the future?

# %% [markdown]
# ### Notes (if any):
